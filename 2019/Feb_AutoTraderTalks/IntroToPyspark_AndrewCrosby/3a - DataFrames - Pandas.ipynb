# %% [markdown]
# # DataFrames - Pandas
#
# Example analysis with the [Movielens](https://grouplens.org/datasets/movielens/) data set to demonstrate common data manipulation steps using Pandas

# %%
import datetime
import os
import urllib
import zipfile
import pandas as pd

# %% [markdown]
# ### Download the Movielens data set

# %%
if not os.path.isdir("data"):
    os.makedirs("data")
    
if not os.path.isfile("data/ml-20m.zip"):
    urllib.request.urlretrieve("http://files.grouplens.org/datasets/movielens/ml-20m.zip", "data/ml-20m.zip")
    zipped_data = zipfile.ZipFile("data/ml-20m.zip", 'r')
    zipped_data.extractall("data")
    zipped_data.close()

# %% [markdown]
# ### Read data from CSV

# %% [markdown]
# Movie dimension table

# %%
movies = pd.read_csv("data/ml-20m/movies.csv")

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %% [markdown]
# Ratings fact table

# %%
ratings = pd.read_csv("data/ml-20m/ratings.csv")

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734
# 7       1      223     4.0  1112485573
# 8       1      253     4.0  1112484940
# 9       1      260     4.0  1112484826

# %% [markdown]
# ### Add a column

# %% [markdown]
# Convert timestamp to a datetime

# %%
ratings["time"] = pd.to_datetime(ratings["timestamp"], unit="s")
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp                time
# 0       1        2     3.5  1112486027 2005-04-02 23:53:47
# 1       1       29     3.5  1112484676 2005-04-02 23:31:16
# 2       1       32     3.5  1112484819 2005-04-02 23:33:39
# 3       1       47     3.5  1112484727 2005-04-02 23:32:07
# 4       1       50     3.5  1112484580 2005-04-02 23:29:40
# 5       1      112     3.5  1094785740 2004-09-10 03:09:00
# 6       1      151     4.0  1094785734 2004-09-10 03:08:54
# 7       1      223     4.0  1112485573 2005-04-02 23:46:13
# 8       1      253     4.0  1112484940 2005-04-02 23:35:40
# 9       1      260     4.0  1112484826 2005-04-02 23:33:46

# %% [markdown]
# ### Filter

# %% [markdown]
# Only include movies that were rated in 2009

# %%
binary_mask = ratings["time"].between(pd.Timestamp(2009,1,1), pd.Timestamp(2010,1,1))
binary_mask.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: time, dtype: bool

# %%
ratingsFiltered = ratings[binary_mask] # View or copy???
ratingsFiltered.head(10)
# Out:
#      userId  movieId  rating   timestamp                time
# 960      11        1     4.5  1230858821 2009-01-02 01:13:41
# 961      11       10     2.5  1230858959 2009-01-02 01:15:59
# 962      11       19     3.5  1230783704 2009-01-01 04:21:44
# 963      11       32     5.0  1230783095 2009-01-01 04:11:35
# 964      11       39     4.5  1230859032 2009-01-02 01:17:12
# 965      11       65     2.0  1230856649 2009-01-02 00:37:29
# 966      11      110     4.0  1230853748 2009-01-01 23:49:08
# 967      11      145     3.0  1230785947 2009-01-01 04:59:07
# 968      11      150     5.0  1230785343 2009-01-01 04:49:03
# 969      11      153     3.5  1230858914 2009-01-02 01:15:14

# %% [markdown]
# ### Group by/Aggregation

# %% [markdown]
# Group by movieId and aggregate to find the total number of ratings and their average value

# %%
averageRatings = ratingsFiltered.groupby("movieId")["rating"]\
                                .agg(["count", "mean"])\
                                .rename({"mean": "averageRating"}, axis=1)\
                                .sort_values("averageRating", ascending=False)
averageRatings.head(10)
# Out:
#          count  averageRating
# movieId
# 1138         1            5.0
# 59           1            5.0
# 68265        1            5.0
# 4922         1            5.0
# 5306         1            5.0
# 8845         1            5.0
# 5405         1            5.0
# 72714        1            5.0
# 2698         1            5.0
# 7989         1            5.0

# %% [markdown]
# ### Filter again

# %% [markdown]
# Only include movies with at least 100 reviews

# %%
averageRatingsFiltered = averageRatings[averageRatings["count"] > 100]
averageRatingsFiltered.head(10)
# Out:
#          count  averageRating
# movieId
# 318       2623       4.439954
# 2959      2709       4.313031
# 296       2556       4.281690
# 6016      1153       4.273634
# 5618       986       4.265720
# 50        1826       4.259036
# 926        141       4.255319
# 1201       682       4.248534
# 858       1851       4.246623
# 44555      664       4.224398

# %% [markdown]
# ### Join

# %% [markdown]
# Join with the movie dimension table

# %%
averageRatingsWithMovie = averageRatingsFiltered.merge(movies, on="movieId", how="inner")\
                                                .sort_values("averageRating", ascending=False)
averageRatingsWithMovie.head(10)
# Out:
#    movieId  count  averageRating  \
# 0      318   2623       4.439954
# 1     2959   2709       4.313031
# 2      296   2556       4.281690
# 3     6016   1153       4.273634
# 4     5618    986       4.265720
# 5       50   1826       4.259036
# 6      926    141       4.255319
# 7     1201    682       4.248534
# 8      858   1851       4.246623
# 9    44555    664       4.224398
#
#                                                title  \
# 0                   Shawshank Redemption, The (1994)
# 1                                  Fight Club (1999)
# 2                                Pulp Fiction (1994)
# 3                City of God (Cidade de Deus) (2002)
# 4  Spirited Away (Sen to Chihiro no kamikakushi) ...
# 5                         Usual Suspects, The (1995)
# 6                               All About Eve (1950)
# 7  Good, the Bad and the Ugly, The (Buono, il bru...
# 8                              Godfather, The (1972)
# 9  Lives of Others, The (Das leben der Anderen) (...
#
#                                   genres
# 0                            Crime|Drama
# 1            Action|Crime|Drama|Thriller
# 2            Comedy|Crime|Drama|Thriller
# 3  Action|Adventure|Crime|Drama|Thriller
# 4            Adventure|Animation|Fantasy
# 5                 Crime|Mystery|Thriller
# 6                                  Drama
# 7               Action|Adventure|Western
# 8                            Crime|Drama
# 9                 Drama|Romance|Thriller

# %% [markdown]
# ### Filter again

# %% [markdown]
# Only include Westerns

# %%
topWesterns = averageRatingsWithMovie[averageRatingsWithMovie["genres"].apply(lambda x: "Western" in x)]
topWesterns.head(10)
# Out:
#      movieId  count  averageRating  \
# 7       1201    682       4.248534
# 19      1209    284       4.163732
# 26      1254    130       4.134615
# 112     1304    313       4.041534
# 118     3681    279       4.035842
# 123     1266    439       4.031891
# 192    26649    195       3.961538
# 194     2951    321       3.961059
# 252      714    156       3.916667
# 257    56782    721       3.911928
#
#                                                  title  \
# 7    Good, the Bad and the Ugly, The (Buono, il bru...
# 19   Once Upon a Time in the West (C'era una volta ...
# 26            Treasure of the Sierra Madre, The (1948)
# 112          Butch Cassidy and the Sundance Kid (1969)
# 118  For a Few Dollars More (Per qualche dollaro in...
# 123                                  Unforgiven (1992)
# 192                               Lonesome Dove (1989)
# 194  Fistful of Dollars, A (Per un pugno di dollari...
# 252                                    Dead Man (1995)
# 257                         There Will Be Blood (2007)
#
#                              genres
# 7          Action|Adventure|Western
# 19             Action|Drama|Western
# 26   Action|Adventure|Drama|Western
# 112                  Action|Western
# 118   Action|Drama|Thriller|Western
# 123                   Drama|Western
# 192         Adventure|Drama|Western
# 194                  Action|Western
# 252           Drama|Mystery|Western
# 257                   Drama|Western
